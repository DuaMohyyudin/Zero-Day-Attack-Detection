# %%
# !pip install numpy pandas scikit-learn tensorflow

# %%
# !git clone https://github.com/AbertayMachineLearningGroup/zero-day-detection.git
# Out:
# fatal: destination path 'zero-day-detection' already exists and is not an empty directory.

# %%
import os

# Change directory to zero-day-detection
os.chdir('/content/zero-day-detection')

# %%
# !ls /content
# Out:
# sample_data  zero-day-detection

# %%
# !pwd
# Out:
# /content/zero-day-detection

# %%
# !python3 main.py --model autoencoder --normal_path DataFiles/CIC/biflow_Monday-WorkingHours_Fixed.csv --attack_paths DataFiles/CIC/ --dataset_path DataFiles/KDD/kddcup.data_10_percent_corrected --output Result.csv --epochs 50 --archi U15,U9,U15 --dropout 0.05 --regu l2 --l1_value 0.01 --l2_value 0.0001 --correlation_value 0.9 --nu 0.01 --kern rbf --loss mse
# Out:
# 2024-12-08 16:17:41.940611: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-08 16:17:41.980021: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-08 16:17:41.991483: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-08 16:17:42.018663: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
